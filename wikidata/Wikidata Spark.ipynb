# %%
import json

# %%
wikidata = sc.textFile('hdfs://hdfs-mesos/data/wikidata-20170313-all.json')

# %%
# Borrowed from @arnes: parser function to turn lines into JSON objects.
def parseLine(line):
    # Parse all lines except the first "[" and last "]"
    if len(line) > 1:
        # Strip tailing comma, except for last element in entire list
        if line[-1:] == ',':
            line = line[:-1]
        try:
            return json.loads(line)
        except:
            raise ValueError('Unable to decode line: {}'.format(line))

# %%
# Borrowed from @arnes: process wikidata and filter away entries where parsing failed.
data = (wikidata.map(parseLine)
        .filter(lambda item: item != False and item != None)
        .filter(lambda entry: entry['type'] == 'item')
        .cache())

print('Number of entries: {}'.format(data.count()))
# Out:
# Number of entries: 25324233

# %%
data.take(1)
# Out:
# [{u'aliases': {u'ar': [{u'language': u'ar',
#      u'value': u'\u0625\u0633\u0643\u062a\u0644\u0646\u062f\u0627'}],
#    u'be-tarask': [{u'language': u'be-tarask',
#      u'value': u'\u0428\u043a\u043e\u0446\u044b\u044f'}],
#    u'ca': [{u'language': u'ca', u'value': u'Scotland'}],
#    u'en': [{u'language': u'en', u'value': u'Alba'},
#     {u'language': u'en', u'value': u'Scotland, United Kingdom'},
#     {u'language': u'en', u'value': u'SCT'},
#     {u'language': u'en', u'value': u'Caledonia'},
#     {u'language': u'en', u'value': u'scot'}],
#    u'en-gb': [{u'language': u'en-gb', u'value': u'Caledonia'}],
#    u'eo': [{u'language': u'eo', u'value': u'Skotio'},
#     {u'language': u'eo', u'value': u'Skotujo'}],
#    u'hr': [{u'language': u'hr', u'value': u'Kaledonija'}],
#    u'kn': [{u'language': u'kn', u'value': u'\u0c86\u0cb2\u0ccd\u0cac\u0cbe'}],
#    u'ta': [{u'language': u'ta', u'value': u'\u0b86\u0bb2\u0bcd\u0baa\u0bbe'}],
#    u'th': [{u'language': u'th',
#      u'value': u'\u0e41\u0e04\u0e27\u0e49\u0e19\u0e2a\u0e01\u0e47\u0e2d\u0e15\u0e41\u0e25\u0e19\u0e14\u0e4c'},
#     {u'language': u'th',
#      u'value': u'\u0e2a\u0e01\u0e47\u0e2d\u0e15\u0e41\u0e25\u0e19\u0e14\u0e4c'},
#     {u'language': u'th',
#      u'value': u'\u0e2a\u0e01\u0e4a\u0e2d\u0e15\u0e41\u0e25\u0e19\u0e14\u0e4c'},
#     {u'language': u'th', u'value': u'Scotland'},
#     {u'language': u'th',
#      u'value': u'\u0e41\u0e04\u0e27\u0e49\u0e19\u0e2a\u0e01\u0e2d\u0e15\u0e41\u0e25\u0e19\u0e14\u0e4c'},
#     {u'language': u'th', u'value': u'\u0e2a\u0e01\u0e47\u0e2d\u0e15'},
#     {u'language': u'th',
#      u'value': u'\u0e1b\u0e23\u0e30\u0e40\u0e17\u0e28\u0e2a\u0e01\u0e47\u0e2d\u0e15\u0e41\u0e25\u0e19\u0e14\u0e4c'},
#     {u'language': u'th',
#      u'value': u'\u0e1b\u0e23\u0e30\u0e40\u0e17\u0e28\u0e2a\u0e01\u0e4a\u0e2d\u0e15\u0e41\u0e25\u0e19\u0e14\u0e4c'}]},
#   u'claims': {u'P1036': [{u'id': u'Q22$7b6061b8-4311-099d-3d2f-3a7de56cf23a',
#      u'mainsnak': {u'datatype': u'string',
#       u'datavalue': {u'type': u'string', u'value': u'2--411'},
#       u'property': u'P1036',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P1151': [{u'id': u'Q22$04c44166-4108-c316-d451-aa9a60524349',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q8143311',
#         u'numeric-id': 8143311}},
#       u'property': u'P1151',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P1245': [{u'id': u'Q22$1230f800-4cb0-aff4-6564-dd7f075411bb',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'374042'},
#       u'property': u'P1245',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P131': [{u'id': u'Q22$2D126F27-49E2-48E1-ABF5-E9E4B412DE0B',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q145',
#         u'numeric-id': 145}},
#       u'property': u'P131',
#       u'snaktype': u'value'},
#      u'qualifiers': {u'P580': [{u'datatype': u'time',
#         u'datavalue': {u'type': u'time',
#          u'value': {u'after': 0,
#           u'before': 0,
#           u'calendarmodel': u'http://www.wikidata.org/entity/Q1985727',
#           u'precision': 11,
#           u'time': u'+1922-12-06T00:00:00Z',
#           u'timezone': 0}},
#         u'hash': u'af4d7ffc66c794ecef0910386f5c0e8923a1eec9',
#         u'property': u'P580',
#         u'snaktype': u'value'}]},
#      u'qualifiers-order': [u'P580'],
#      u'rank': u'preferred',
#      u'type': u'statement'},
#     {u'id': u'Q22$A6846254-E781-4690-9F53-CCB1839973C1',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q174193',
#         u'numeric-id': 174193}},
#       u'property': u'P131',
#       u'snaktype': u'value'},
#      u'qualifiers': {u'P580': [{u'datatype': u'time',
#         u'datavalue': {u'type': u'time',
#          u'value': {u'after': 0,
#           u'before': 0,
#           u'calendarmodel': u'http://www.wikidata.org/entity/Q1985727',
#           u'precision': 11,
#           u'time': u'+1800-12-31T00:00:00Z',
#           u'timezone': 0}},
#         u'hash': u'7ca691f7ff4b3433b85ee755d5b913e57ba02065',
#         u'property': u'P580',
#         u'snaktype': u'value'}],
#       u'P582': [{u'datatype': u'time',
#         u'datavalue': {u'type': u'time',
#          u'value': {u'after': 0,
#           u'before': 0,
#           u'calendarmodel': u'http://www.wikidata.org/entity/Q1985727',
#           u'precision': 11,
#           u'time': u'+1922-12-06T00:00:00Z',
#           u'timezone': 0}},
#         u'hash': u'95787570ef6c42cc524b335b9502e94aff3f513e',
#         u'property': u'P582',
#         u'snaktype': u'value'}]},
#      u'qualifiers-order': [u'P580', u'P582'],
#      u'rank': u'normal',
#      u'type': u'statement'},
#     {u'id': u'Q22$706bae70-404a-4c32-0dfb-b8d0d06fbc8a',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q161885',
#         u'numeric-id': 161885}},
#       u'property': u'P131',
#       u'snaktype': u'value'},
#      u'qualifiers': {u'P580': [{u'datatype': u'time',
#         u'datavalue': {u'type': u'time',
#          u'value': {u'after': 0,
#           u'before': 0,
#           u'calendarmodel': u'http://www.wikidata.org/entity/Q1985727',
#           u'precision': 11,
#           u'time': u'+1707-01-01T00:00:00Z',
#           u'timezone': 0}},
#         u'hash': u'6d9c2b499b6326252198a8ffbdd72e05c40350e0',
#         u'property': u'P580',
#         u'snaktype': u'value'}],
#       u'P582': [{u'datatype': u'time',
#         u'datavalue': {u'type': u'time',
#          u'value': {u'after': 0,
#           u'before': 0,
#           u'calendarmodel': u'http://www.wikidata.org/entity/Q1985727',
#           u'precision': 11,
#           u'time': u'+1800-12-31T00:00:00Z',
#           u'timezone': 0}},
#         u'hash': u'516b51468cccf3f32a72830cfcc672366e3b615e',
#         u'property': u'P582',
#         u'snaktype': u'value'}]},
#      u'qualifiers-order': [u'P580', u'P582'],
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P1365': [{u'id': u'Q22$745eeda7-47fc-8a9e-9657-1435027b16d5',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q230791',
#         u'numeric-id': 230791}},
#       u'property': u'P1365',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P1417': [{u'id': u'Q22$145523FE-9C4D-479E-B691-DBEB2192005D',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'place/Scotland'},
#       u'property': u'P1417',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P1464': [{u'id': u'Q22$6EFD869C-8648-4501-9B5B-4552E3CCF983',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q8079733',
#         u'numeric-id': 8079733}},
#       u'property': u'P1464',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'd6e3ab4045fb3f3feea77895bc6b27e663fc878a',
#        u'snaks': {u'P143': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q206855',
#             u'numeric-id': 206855}},
#           u'property': u'P143',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P143']}],
#      u'type': u'statement'}],
#    u'P1465': [{u'id': u'Q22$EA1EE3C4-4EEA-496C-8A2C-C5C6ED4B21EC',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q8365629',
#         u'numeric-id': 8365629}},
#       u'property': u'P1465',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'd6e3ab4045fb3f3feea77895bc6b27e663fc878a',
#        u'snaks': {u'P143': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q206855',
#             u'numeric-id': 206855}},
#           u'property': u'P143',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P143']}],
#      u'type': u'statement'}],
#    u'P150': [{u'id': u'Q22$9B74621A-901C-4BC6-9589-46399A581A64',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q100166',
#         u'numeric-id': 100166}},
#       u'property': u'P150',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P1546': [{u'id': u'Q22$811a36c6-4cf0-e32a-f2a2-1cb82d5f9201',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q2016568',
#         u'numeric-id': 2016568}},
#       u'property': u'P1546',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P1549': [{u'id': u'Q22$540b079c-43d8-e0ca-43b2-431f1a9f41f6',
#      u'mainsnak': {u'datatype': u'monolingualtext',
#       u'datavalue': {u'type': u'monolingualtext',
#        u'value': {u'language': u'en', u'text': u'Scottish'}},
#       u'property': u'P1549',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'},
#     {u'id': u'Q22$07dd176b-4efa-9af4-2d9e-4e2d6129fe67',
#      u'mainsnak': {u'datatype': u'monolingualtext',
#       u'datavalue': {u'type': u'monolingualtext',
#        u'value': {u'language': u'de', u'text': u'schottisch'}},
#       u'property': u'P1549',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'},
#     {u'id': u'Q22$f45ecb5e-46a6-b7e5-7c8f-a329c39fe3af',
#      u'mainsnak': {u'datatype': u'monolingualtext',
#       u'datavalue': {u'type': u'monolingualtext',
#        u'value': {u'language': u'de', u'text': u'Schotte'}},
#       u'property': u'P1549',
#       u'snaktype': u'value'},
#      u'qualifiers': {u'P518': [{u'datatype': u'wikibase-item',
#         u'datavalue': {u'type': u'wikibase-entityid',
#          u'value': {u'entity-type': u'item',
#           u'id': u'Q499327',
#           u'numeric-id': 499327}},
#         u'hash': u'133d68449dc203e66879c8659213fa153b8639bd',
#         u'property': u'P518',
#         u'snaktype': u'value'}]},
#      u'qualifiers-order': [u'P518'],
#      u'rank': u'normal',
#      u'type': u'statement'},
#     {u'id': u'Q22$09fdcd8d-479c-3189-f3a5-5505b2a5d0cc',
#      u'mainsnak': {u'datatype': u'monolingualtext',
#       u'datavalue': {u'type': u'monolingualtext',
#        u'value': {u'language': u'de', u'text': u'Schottin'}},
#       u'property': u'P1549',
#       u'snaktype': u'value'},
#      u'qualifiers': {u'P518': [{u'datatype': u'wikibase-item',
#         u'datavalue': {u'type': u'wikibase-entityid',
#          u'value': {u'entity-type': u'item',
#           u'id': u'Q1775415',
#           u'numeric-id': 1775415}},
#         u'hash': u'e630ba8dd1a9df90e9870fbabc11fcdf369dc2eb',
#         u'property': u'P518',
#         u'snaktype': u'value'}]},
#      u'qualifiers-order': [u'P518'],
#      u'rank': u'normal',
#      u'type': u'statement'},
#     {u'id': u'Q22$8868b176-41db-2879-ed24-e1ec508a0948',
#      u'mainsnak': {u'datatype': u'monolingualtext',
#       u'datavalue': {u'type': u'monolingualtext',
#        u'value': {u'language': u'nl', u'text': u'Schot'}},
#       u'property': u'P1549',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'},
#     {u'id': u'Q22$7bb3201d-4dc7-3af9-a9a7-9ffb8e860d97',
#      u'mainsnak': {u'datatype': u'monolingualtext',
#       u'datavalue': {u'type': u'monolingualtext',
#        u'value': {u'language': u'fr', u'text': u'\xc9cossais'}},
#       u'property': u'P1549',
#       u'snaktype': u'value'},
#      u'qualifiers': {u'P518': [{u'datatype': u'wikibase-item',
#         u'datavalue': {u'type': u'wikibase-entityid',
#          u'value': {u'entity-type': u'item',
#           u'id': u'Q6581097',
#           u'numeric-id': 6581097}},
#         u'hash': u'5489b3771ebd30aa4b97f5261dd9b4df86b940e0',
#         u'property': u'P518',
#         u'snaktype': u'value'}]},
#      u'qualifiers-order': [u'P518'],
#      u'rank': u'normal',
#      u'type': u'statement'},
#     {u'id': u'Q22$c297fb86-4ed1-cf3a-2827-23c547b28453',
#      u'mainsnak': {u'datatype': u'monolingualtext',
#       u'datavalue': {u'type': u'monolingualtext',
#        u'value': {u'language': u'fr', u'text': u'\xc9cossaise'}},
#       u'property': u'P1549',
#       u'snaktype': u'value'},
#      u'qualifiers': {u'P518': [{u'datatype': u'wikibase-item',
#         u'datavalue': {u'type': u'wikibase-entityid',
#          u'value': {u'entity-type': u'item',
#           u'id': u'Q6581072',
#           u'numeric-id': 6581072}},
#         u'hash': u'cfcb1383c00fefb4e19a71e5025c154fd13a6d76',
#         u'property': u'P518',
#         u'snaktype': u'value'}]},
#      u'qualifiers-order': [u'P518'],
#      u'rank': u'normal',
#      u'type': u'statement'},
#     {u'id': u'Q22$6ad11fb0-42db-5bc5-186e-94d3a17107db',
#      u'mainsnak': {u'datatype': u'monolingualtext',
#       u'datavalue': {u'type': u'monolingualtext',
#        u'value': {u'language': u'hu', u'text': u'sk\xf3t'}},
#       u'property': u'P1549',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'},
#     {u'id': u'Q22$a4536c75-4b34-e78a-fadc-fc48049e3d36',
#      u'mainsnak': {u'datatype': u'monolingualtext',
#       u'datavalue': {u'type': u'monolingualtext',
#        u'value': {u'language': u'el',
#         u'text': u'\u03c3\u03ba\u03c9\u03c4\u03c3\u03ad\u03b6\u03bf\u03c2'}},
#       u'property': u'P1549',
#       u'snaktype': u'value'},
#      u'qualifiers': {u'P518': [{u'datatype': u'wikibase-item',
#         u'datavalue': {u'type': u'wikibase-entityid',
#          u'value': {u'entity-type': u'item',
#           u'id': u'Q6581097',
#           u'numeric-id': 6581097}},
#         u'hash': u'5489b3771ebd30aa4b97f5261dd9b4df86b940e0',
#         u'property': u'P518',
#         u'snaktype': u'value'}]},
#      u'qualifiers-order': [u'P518'],
#      u'rank': u'normal',
#      u'type': u'statement'},
#     {u'id': u'Q22$4362a929-4ac4-9901-c597-a24de34b0146',
#      u'mainsnak': {u'datatype': u'monolingualtext',
#       u'datavalue': {u'type': u'monolingualtext',
#        u'value': {u'language': u'el',
#         u'text': u'\u03c3\u03ba\u03c9\u03c4\u03c3\u03ad\u03b6\u03b1'}},
#       u'property': u'P1549',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'},
#     {u'id': u'Q22$f96f94a0-4d1f-8b64-6eb9-4df808b0084e',
#      u'mainsnak': {u'datatype': u'monolingualtext',
#       u'datavalue': {u'type': u'monolingualtext',
#        u'value': {u'language': u'bg',
#         u'text': u'\u0448\u043e\u0442\u043b\u0430\u043d\u0434\u0446\u0438'}},
#       u'property': u'P1549',
#       u'snaktype': u'value'},
#      u'qualifiers': {u'P518': [{u'datatype': u'wikibase-item',
#         u'datavalue': {u'type': u'wikibase-entityid',
#          u'value': {u'entity-type': u'item',
#           u'id': u'Q146786',
#           u'numeric-id': 146786}},
#         u'hash': u'71981b02892bf9fbf351fd1ec0624f6e1b665533',
#         u'property': u'P518',
#         u'snaktype': u'value'}]},
#      u'qualifiers-order': [u'P518'],
#      u'rank': u'normal',
#      u'type': u'statement'},
#     {u'id': u'Q22$0059bfc7-4e69-7380-af10-c8c7b0b85e91',
#      u'mainsnak': {u'datatype': u'monolingualtext',
#       u'datavalue': {u'type': u'monolingualtext',
#        u'value': {u'language': u'bg',
#         u'text': u'\u0448\u043e\u0442\u043b\u0430\u043d\u0434\u0435\u0446'}},
#       u'property': u'P1549',
#       u'snaktype': u'value'},
#      u'qualifiers': {u'P518': [{u'datatype': u'wikibase-item',
#         u'datavalue': {u'type': u'wikibase-entityid',
#          u'value': {u'entity-type': u'item',
#           u'id': u'Q499327',
#           u'numeric-id': 499327}},
#         u'hash': u'133d68449dc203e66879c8659213fa153b8639bd',
#         u'property': u'P518',
#         u'snaktype': u'value'}]},
#      u'qualifiers-order': [u'P518'],
#      u'rank': u'normal',
#      u'type': u'statement'},
#     {u'id': u'Q22$627d00cc-4811-c939-f118-9f036590e47c',
#      u'mainsnak': {u'datatype': u'monolingualtext',
#       u'datavalue': {u'type': u'monolingualtext',
#        u'value': {u'language': u'bg',
#         u'text': u'\u0448\u043e\u0442\u043b\u0430\u043d\u0434\u043a\u0430'}},
#       u'property': u'P1549',
#       u'snaktype': u'value'},
#      u'qualifiers': {u'P518': [{u'datatype': u'wikibase-item',
#         u'datavalue': {u'type': u'wikibase-entityid',
#          u'value': {u'entity-type': u'item',
#           u'id': u'Q1775415',
#           u'numeric-id': 1775415}},
#         u'hash': u'e630ba8dd1a9df90e9870fbabc11fcdf369dc2eb',
#         u'property': u'P518',
#         u'snaktype': u'value'}]},
#      u'qualifiers-order': [u'P518'],
#      u'rank': u'normal',
#      u'type': u'statement'},
#     {u'id': u'Q22$8d316350-4fa1-cc5f-4e21-17827dbb9b5b',
#      u'mainsnak': {u'datatype': u'monolingualtext',
#       u'datavalue': {u'type': u'monolingualtext',
#        u'value': {u'language': u'he',
#         u'text': u'\u05e1\u05e7\u05d5\u05d8\u05d9\u05ea'}},
#       u'property': u'P1549',
#       u'snaktype': u'value'},
#      u'qualifiers': {u'P518': [{u'datatype': u'wikibase-item',
#         u'datavalue': {u'type': u'wikibase-entityid',
#          u'value': {u'entity-type': u'item',
#           u'id': u'Q6581072',
#           u'numeric-id': 6581072}},
#         u'hash': u'cfcb1383c00fefb4e19a71e5025c154fd13a6d76',
#         u'property': u'P518',
#         u'snaktype': u'value'}]},
#      u'qualifiers-order': [u'P518'],
#      u'rank': u'normal',
#      u'type': u'statement'},
#     {u'id': u'Q22$269d5658-44d2-fdbb-8789-471bfcd04300',
#      u'mainsnak': {u'datatype': u'monolingualtext',
#       u'datavalue': {u'type': u'monolingualtext',
#        u'value': {u'language': u'he',
#         u'text': u'\u05e1\u05e7\u05d5\u05d8\u05d9'}},
#       u'property': u'P1549',
#       u'snaktype': u'value'},
#      u'qualifiers': {u'P518': [{u'datatype': u'wikibase-item',
#         u'datavalue': {u'type': u'wikibase-entityid',
#          u'value': {u'entity-type': u'item',
#           u'id': u'Q6581097',
#           u'numeric-id': 6581097}},
#         u'hash': u'5489b3771ebd30aa4b97f5261dd9b4df86b940e0',
#         u'property': u'P518',
#         u'snaktype': u'value'}]},
#      u'qualifiers-order': [u'P518'],
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P1566': [{u'id': u'Q22$B1B9EA32-0EFD-40A6-96C6-FE6BA3021EF2',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'2638360'},
#       u'property': u'P1566',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'd6193e4d78598db1a6aaa453fface1553022f1f2',
#        u'snaks': {u'P143': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q830106',
#             u'numeric-id': 830106}},
#           u'property': u'P143',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P143']}],
#      u'type': u'statement'}],
#    u'P159': [{u'id': u'Q22$3ccd9e56-45a5-6714-8d66-e9fd8bf2be1a',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q2379199',
#         u'numeric-id': 2379199}},
#       u'property': u'P159',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P163': [{u'id': u'q22$1117feb8-44e3-1284-7f65-8189afacf4c9',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q102392',
#         u'numeric-id': 102392}},
#       u'property': u'P163',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P17': [{u'id': u'q22$91B568B9-887D-4CD7-9534-AD889A997974',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q145',
#         u'numeric-id': 145}},
#       u'property': u'P17',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P1711': [{u'id': u'Q22$8022FBAC-5FB2-4609-86B7-E93D01DC6D92',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'114921'},
#       u'property': u'P1711',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P1740': [{u'id': u'Q22$20784E2D-5910-45B6-9A0A-0839522C66E2',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q6427237',
#         u'numeric-id': 6427237}},
#       u'property': u'P1740',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P1792': [{u'id': u'Q22$01DA3438-8BD8-439C-822A-1424A7ED43F8',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q7030374',
#         u'numeric-id': 7030374}},
#       u'property': u'P1792',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'd6e3ab4045fb3f3feea77895bc6b27e663fc878a',
#        u'snaks': {u'P143': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q206855',
#             u'numeric-id': 206855}},
#           u'property': u'P143',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P143']}],
#      u'type': u'statement'}],
#    u'P18': [{u'id': u'Q22$1573baad-472f-cd6f-66f8-702a7f7c37f7',
#      u'mainsnak': {u'datatype': u'commonsMedia',
#       u'datavalue': {u'type': u'string',
#        u'value': u'Highlands (6194583897).jpg'},
#       u'property': u'P18',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P194': [{u'id': u'q22$EFF61018-8671-44DE-836B-E9D30F0A0987',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q206171',
#         u'numeric-id': 206171}},
#       u'property': u'P194',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P2046': [{u'id': u'Q22$13C0B1FE-B78C-4CB5-A887-F228810729BF',
#      u'mainsnak': {u'datatype': u'quantity',
#       u'datavalue': {u'type': u'quantity',
#        u'value': {u'amount': u'+78782',
#         u'unit': u'http://www.wikidata.org/entity/Q712226'}},
#       u'property': u'P2046',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'50f57a3dbac4708ce4ae4a827c0afac7fcdb4a5c',
#        u'snaks': {u'P143': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q11920',
#             u'numeric-id': 11920}},
#           u'property': u'P143',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P143']}],
#      u'type': u'statement'}],
#    u'P214': [{u'id': u'Q22$D3D2AFA5-4FC0-4BD4-A37B-C2620D3BC40E',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'258766271'},
#       u'property': u'P214',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'a51d6594fee36c7452eaed2db35a4833613a7078',
#        u'snaks': {u'P143': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q54919',
#             u'numeric-id': 54919}},
#           u'property': u'P143',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P143']}],
#      u'type': u'statement'}],
#    u'P2163': [{u'id': u'Q22$22ce081a-4a73-d1e8-69a3-d408d7591e2f',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'1206715'},
#       u'property': u'P2163',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P2184': [{u'id': u'Q22$93d1b013-402d-5f89-83a5-c92e29fbe333',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q471148',
#         u'numeric-id': 471148}},
#       u'property': u'P2184',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P227': [{u'id': u'Q22$6CEDA9B1-FDF1-4F92-B258-FE57DC04CB33',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'4053233-1'},
#       u'property': u'P227',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'004ec6fbee857649acdbdbad4f97b2c8571df97b',
#        u'snaks': {u'P143': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q48183',
#             u'numeric-id': 48183}},
#           u'property': u'P143',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P143']}],
#      u'type': u'statement'}],
#    u'P237': [{u'id': u'Q22$96E0CC80-BA6D-4607-A363-557B226DEE7A',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q217529',
#         u'numeric-id': 217529}},
#       u'property': u'P237',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'd6e3ab4045fb3f3feea77895bc6b27e663fc878a',
#        u'snaks': {u'P143': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q206855',
#             u'numeric-id': 206855}},
#           u'property': u'P143',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P143']}],
#      u'type': u'statement'}],
#    u'P242': [{u'id': u'q22$667A95F0-5667-4414-8723-55BE4144753E',
#      u'mainsnak': {u'datatype': u'commonsMedia',
#       u'datavalue': {u'type': u'string',
#        u'value': u'Scotland in the UK and Europe.svg'},
#       u'property': u'P242',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P244': [{u'id': u'Q22$0FAAB6C4-424E-4EB5-8163-B6C08109C841',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'n79123936'},
#       u'property': u'P244',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'7888a7c574f4f0e64d4fd14f653320585aa53411',
#        u'snaks': {u'P248': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q3294867',
#             u'numeric-id': 3294867}},
#           u'property': u'P248',
#           u'snaktype': u'value'}],
#         u'P813': [{u'datatype': u'time',
#           u'datavalue': {u'type': u'time',
#            u'value': {u'after': 0,
#             u'before': 0,
#             u'calendarmodel': u'http://www.wikidata.org/entity/Q1985727',
#             u'precision': 11,
#             u'time': u'+2016-11-26T00:00:00Z',
#             u'timezone': 0}},
#           u'property': u'P813',
#           u'snaktype': u'value'}],
#         u'P854': [{u'datatype': u'url',
#           u'datavalue': {u'type': u'string',
#            u'value': u'http://id.worldcat.org/fast/1206715'},
#           u'property': u'P854',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P248', u'P813', u'P854']}],
#      u'type': u'statement'}],
#    u'P2633': [{u'id': u'Q22$85d2636f-4b89-970b-39ee-fae5086ce6c3',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q2118306',
#         u'numeric-id': 2118306}},
#       u'property': u'P2633',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P2959': [{u'id': u'Q22$11E6141E-98BB-4CC7-BB77-339605DDE8B1',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q27103360',
#         u'numeric-id': 27103360}},
#       u'property': u'P2959',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P2997': [{u'id': u'Q22$F3192AC9-61E1-423B-A5C7-0983C6A46D6E',
#      u'mainsnak': {u'datatype': u'quantity',
#       u'datavalue': {u'type': u'quantity',
#        u'value': {u'amount': u'+16',
#         u'lowerBound': u'+16',
#         u'unit': u'http://www.wikidata.org/entity/Q24564698',
#         u'upperBound': u'+16'}},
#       u'property': u'P2997',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'004ec6fbee857649acdbdbad4f97b2c8571df97b',
#        u'snaks': {u'P143': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q48183',
#             u'numeric-id': 48183}},
#           u'property': u'P143',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P143']}],
#      u'type': u'statement'}],
#    u'P30': [{u'id': u'q22$97BA3354-756D-4CC4-BB8D-F703911A1372',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item', u'id': u'Q46', u'numeric-id': 46}},
#       u'property': u'P30',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P300': [{u'id': u'q22$76317E05-3A77-4A7C-B244-D52CC56390E4',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'GB-SCT'},
#       u'property': u'P300',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P31': [{u'id': u'q22$A821BE15-C339-44BC-9DF7-BC573756C882',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q3336843',
#         u'numeric-id': 3336843}},
#       u'property': u'P31',
#       u'snaktype': u'value'},
#      u'rank': u'preferred',
#      u'type': u'statement'}],
#    u'P3106': [{u'id': u'Q22$73ead9fc-43f9-5a3d-0feb-03c71ffc8857',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'uk/scotland'},
#       u'property': u'P3106',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P3222': [{u'id': u'Q22$f8bb3fe9-4351-14f9-b163-e4623cee2dc7',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'skottland'},
#       u'property': u'P3222',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P3417': [{u'id': u'Q22$400846C5-9031-4B26-8041-C695FDF38072',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'Scotland'},
#       u'property': u'P3417',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P349': [{u'id': u'Q22$B9AACD11-0E08-4E69-8DF0-B43A9ACEBF6E',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'00571670'},
#       u'property': u'P349',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P36': [{u'id': u'q22$CF4B0864-5A40-400C-8611-75B6C02BE547',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q23436',
#         u'numeric-id': 23436}},
#       u'property': u'P36',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P3616': [{u'id': u'Q22$4758AA05-F608-46F5-B434-E9F8BF2D5146',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'20005'},
#       u'property': u'P3616',
#       u'snaktype': u'value'},
#      u'qualifiers': {u'P1810': [{u'datatype': u'string',
#         u'datavalue': {u'type': u'string', u'value': u'Scotland'},
#         u'hash': u'48c10e3926204ad382c29078a3571361e697f994',
#         u'property': u'P1810',
#         u'snaktype': u'value'}]},
#      u'qualifiers-order': [u'P1810'],
#      u'rank': u'normal',
#      u'references': [{u'hash': u'48f39b82a78ac42d49a006ac3e8241e195dcdf83',
#        u'snaks': {u'P813': [{u'datatype': u'time',
#           u'datavalue': {u'type': u'time',
#            u'value': {u'after': 0,
#             u'before': 0,
#             u'calendarmodel': u'http://www.wikidata.org/entity/Q1985727',
#             u'precision': 11,
#             u'time': u'+2017-03-01T00:00:00Z',
#             u'timezone': 0}},
#           u'property': u'P813',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P813']}],
#      u'type': u'statement'}],
#    u'P37': [{u'id': u'q22$BFD3EA7E-9741-48BE-910B-308137EF8534',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q1860',
#         u'numeric-id': 1860}},
#       u'property': u'P37',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P373': [{u'id': u'q22$F97976BA-AC40-4EC0-8467-55FCB536E7A5',
#      u'mainsnak': {u'datatype': u'string',
#       u'datavalue': {u'type': u'string', u'value': u'Scotland'},
#       u'property': u'P373',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P38': [{u'id': u'q22$4390E4B0-AC11-47D0-9936-929EF4663FF9',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q25224',
#         u'numeric-id': 25224}},
#       u'property': u'P38',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P402': [{u'id': u'q22$a951daf6-43c9-10e7-105e-05f0177c64b7',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'58446'},
#       u'property': u'P402',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'd7fd1482f6569c150f6503d40dbe0ce2180a5f53',
#        u'snaks': {u'P143': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q936',
#             u'numeric-id': 936}},
#           u'property': u'P143',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P143']}],
#      u'type': u'statement'}],
#    u'P41': [{u'id': u'q22$25AD17CE-BED3-4E2C-B630-9848EE3D5E42',
#      u'mainsnak': {u'datatype': u'commonsMedia',
#       u'datavalue': {u'type': u'string', u'value': u'Flag of Scotland.svg'},
#       u'property': u'P41',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P417': [{u'id': u'Q22$bf5831e2-4ef7-87ee-ace6-6ec593fa31bb',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q43399',
#         u'numeric-id': 43399}},
#       u'property': u'P417',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P421': [{u'id': u'q22$691C22CC-E90D-4BDD-BE1B-15B594CCDF9C',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q6574',
#         u'numeric-id': 6574}},
#       u'property': u'P421',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'50f57a3dbac4708ce4ae4a827c0afac7fcdb4a5c',
#        u'snaks': {u'P143': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q11920',
#             u'numeric-id': 11920}},
#           u'property': u'P143',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P143']}],
#      u'type': u'statement'},
#     {u'id': u'Q22$6658ad20-434b-eef1-91ff-c39cb2915f1c',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q16894228',
#         u'numeric-id': 16894228}},
#       u'property': u'P421',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P47': [{u'id': u'q22$E3F9566A-B51E-4775-B756-5D46A4285AC8',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item', u'id': u'Q21', u'numeric-id': 21}},
#       u'property': u'P47',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P474': [{u'id': u'Q22$f07c41de-48a2-c7d0-cc57-9a9d5c8fd028',
#      u'mainsnak': {u'datatype': u'string',
#       u'datavalue': {u'type': u'string', u'value': u'+44'},
#       u'property': u'P474',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'd6e3ab4045fb3f3feea77895bc6b27e663fc878a',
#        u'snaks': {u'P143': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q206855',
#             u'numeric-id': 206855}},
#           u'property': u'P143',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P143']}],
#      u'type': u'statement'}],
#    u'P605': [{u'id': u'Q22$A0411A97-FBC4-4382-9000-C7935DA5D989',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'UKM'},
#       u'property': u'P605',
#       u'snaktype': u'value'},
#      u'qualifiers': {u'P580': [{u'datatype': u'time',
#         u'datavalue': {u'type': u'time',
#          u'value': {u'after': 0,
#           u'before': 0,
#           u'calendarmodel': u'http://www.wikidata.org/entity/Q1985727',
#           u'precision': 11,
#           u'time': u'+1999-01-01T00:00:00Z',
#           u'timezone': 0}},
#         u'hash': u'faced56e0acdac79e4c00fb98304c15a0119365e',
#         u'property': u'P580',
#         u'snaktype': u'value'}]},
#      u'qualifiers-order': [u'P580'],
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P610': [{u'id': u'Q22$1a6ffab1-41b6-73f5-ea7b-15efd9f02a0d',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q104674',
#         u'numeric-id': 104674}},
#       u'property': u'P610',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P625': [{u'id': u'q22$327258B4-7023-4189-984B-E3A4A5E74B92',
#      u'mainsnak': {u'datatype': u'globe-coordinate',
#       u'datavalue': {u'type': u'globecoordinate',
#        u'value': {u'altitude': None,
#         u'globe': u'http://www.wikidata.org/entity/Q2',
#         u'latitude': 57,
#         u'longitude': -5,
#         u'precision': 1e-05}},
#       u'property': u'P625',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'223f43a7229297bd67ffab922174f80c722fff1a',
#        u'snaks': {u'P143': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q10000',
#             u'numeric-id': 10000}},
#           u'property': u'P143',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P143']}],
#      u'type': u'statement'}],
#    u'P646': [{u'id': u'Q22$E1222411-F8C4-4AC9-B193-A7518ABBC8AA',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'/m/06q1r'},
#       u'property': u'P646',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'af38848ab5d9d9325cffd93a5ec656cc6ca889ed',
#        u'snaks': {u'P248': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q15241312',
#             u'numeric-id': 15241312}},
#           u'property': u'P248',
#           u'snaktype': u'value'}],
#         u'P577': [{u'datatype': u'time',
#           u'datavalue': {u'type': u'time',
#            u'value': {u'after': 0,
#             u'before': 0,
#             u'calendarmodel': u'http://www.wikidata.org/entity/Q1985727',
#             u'precision': 11,
#             u'time': u'+2013-10-28T00:00:00Z',
#             u'timezone': 0}},
#           u'property': u'P577',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P248', u'P577']}],
#      u'type': u'statement'}],
#    u'P78': [{u'id': u'Q22$38445BD8-159D-4830-8D38-DB9D2D562920',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q37913',
#         u'numeric-id': 37913}},
#       u'property': u'P78',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'd6e3ab4045fb3f3feea77895bc6b27e663fc878a',
#        u'snaks': {u'P143': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q206855',
#             u'numeric-id': 206855}},
#           u'property': u'P143',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P143']}],
#      u'type': u'statement'},
#     {u'id': u'Q22$d5ef8b1c-4b54-22cb-ae75-9708a2ac8148',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q937870',
#         u'numeric-id': 937870}},
#       u'property': u'P78',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P836': [{u'id': u'Q22$63f4c1dc-4943-7607-d2fb-af035ff6c702',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string', u'value': u'S92000003'},
#       u'property': u'P836',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'91c8af7794dc47f756a51d4062fa92a0027bc6c1',
#        u'snaks': {u'P854': [{u'datatype': u'url',
#           u'datavalue': {u'type': u'string',
#            u'value': u'http://data.ordnancesurvey.co.uk/doc/country/scotland'},
#           u'property': u'P854',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P854']}],
#      u'type': u'statement'}],
#    u'P85': [{u'id': u'Q22$FE731620-3355-40F4-ACFF-EBBA713F75A0',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q208275',
#         u'numeric-id': 208275}},
#       u'property': u'P85',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'7eb64cf9621d34c54fd4bd040ed4b61a88c4a1a0',
#        u'snaks': {u'P143': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q328',
#             u'numeric-id': 328}},
#           u'property': u'P143',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P143']}],
#      u'type': u'statement'}],
#    u'P856': [{u'id': u'Q22$CCFA116F-7B7B-4EDE-B68B-DEBB463D96AA',
#      u'mainsnak': {u'datatype': u'url',
#       u'datavalue': {u'type': u'string',
#        u'value': u'http://www.scotland.org/'},
#       u'property': u'P856',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P910': [{u'id': u'Q22$C9DEC4E0-01E1-4E3A-A97F-91FBFE4F3598',
#      u'mainsnak': {u'datatype': u'wikibase-item',
#       u'datavalue': {u'type': u'wikibase-entityid',
#        u'value': {u'entity-type': u'item',
#         u'id': u'Q7311958',
#         u'numeric-id': 7311958}},
#       u'property': u'P910',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P935': [{u'id': u'Q22$D6C8E97B-EAC5-44DB-A306-3B8B6F467355',
#      u'mainsnak': {u'datatype': u'string',
#       u'datavalue': {u'type': u'string', u'value': u'Scotland'},
#       u'property': u'P935',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P94': [{u'id': u'q22$66C80B4D-4280-455B-94A7-5C18927DC492',
#      u'mainsnak': {u'datatype': u'commonsMedia',
#       u'datavalue': {u'type': u'string',
#        u'value': u'Royal Coat of Arms of the Kingdom of Scotland.svg'},
#       u'property': u'P94',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'd6e3ab4045fb3f3feea77895bc6b27e663fc878a',
#        u'snaks': {u'P143': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q206855',
#             u'numeric-id': 206855}},
#           u'property': u'P143',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P143']}],
#      u'type': u'statement'}],
#    u'P948': [{u'id': u'Q22$8F5B9401-9E64-47C4-B218-DF0AF52CC5CE',
#      u'mainsnak': {u'datatype': u'commonsMedia',
#       u'datavalue': {u'type': u'string',
#        u'value': u'Eilean Donan Castle banner.jpg'},
#       u'property': u'P948',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}],
#    u'P982': [{u'id': u'Q22$1EEDF0B4-801E-4085-9009-A4B84D16E9C8',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string',
#        u'value': u'6fa1c7da-6689-4cec-85f9-680f853e8a08'},
#       u'property': u'P982',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'references': [{u'hash': u'73057782312f850e2ed69c4c28ad162f57f6d390',
#        u'snaks': {u'P248': [{u'datatype': u'wikibase-item',
#           u'datavalue': {u'type': u'wikibase-entityid',
#            u'value': {u'entity-type': u'item',
#             u'id': u'Q14005',
#             u'numeric-id': 14005}},
#           u'property': u'P248',
#           u'snaktype': u'value'}]},
#        u'snaks-order': [u'P248']}],
#      u'type': u'statement'}],
#    u'P998': [{u'id': u'Q22$78EC0E7E-9F33-424D-9D26-D06CDF1DFA8B',
#      u'mainsnak': {u'datatype': u'external-id',
#       u'datavalue': {u'type': u'string',
#        u'value': u'Regional/Europe/United_Kingdom/Scotland/'},
#       u'property': u'P998',
#       u'snaktype': u'value'},
#      u'rank': u'normal',
#      u'type': u'statement'}]},
#   u'descriptions': {u'bg': {u'language': u'bg',
#     u'value': u'\u0447\u0430\u0441\u0442 \u043e\u0442 \u041e\u0431\u0435\u0434\u0438\u043d\u0435\u043d\u043e\u0442\u043e \u043a\u0440\u0430\u043b\u0441\u0442\u0432\u043e \u0412\u0435\u043b\u0438\u043a\u043e\u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f \u0438 \u0421\u0435\u0432\u0435\u0440\u043d\u0430 \u0418\u0440\u043b\u0430\u043d\u0434\u0438\u044f'},
#    u'ca': {u'language': u'ca', u'value': u'pa\xeds europeu del Regne Unit'},
#    u'cy': {u'language': u'cy',
#     u'value': u"gwlad yng ngogledd Ewrop, rhan o'r Deyrnas Unedig"},
#    u'de': {u'language': u'de',
#     u'value': u'Landesteil im Vereinigten K\xf6nigreich Gro\xdfbritannien und Nordirland'},
#    u'el': {u'language': u'el',
#     u'value': u'\u03a7\u03ce\u03c1\u03b1 \u03c4\u03b7\u03c2 \u0392\u03cc\u03c1\u03b5\u03b9\u03b1\u03c2 \u0395\u03c5\u03c1\u03ce\u03c0\u03b7\u03c2, \u03bc\u03ad\u03c1\u03bf\u03c2 \u03c4\u03bf\u03c5 \u0397\u03bd\u03c9\u03bc\u03ad\u03bd\u03bf\u03c5 \u0392\u03b1\u03c3\u03b9\u03bb\u03b5\u03af\u03bf\u03c5'},
#    u'en': {u'language': u'en',
#     u'value': u'country in North-West Europe, part of the United Kingdom'},
#    u'en-gb': {u'language': u'en-gb',
#     u'value': u'country in north-west Europe, part of the United Kingdom'},
# ...
#     u'site': u'euwiki',
#     u'title': u'Eskozia'},
#    u'extwiki': {u'badges': [], u'site': u'extwiki', u'title': u'Escocia'},
#    u'fawiki': {u'badges': [],
#     u'site': u'fawiki',
#     u'title': u'\u0627\u0633\u06a9\u0627\u062a\u0644\u0646\u062f'},
#    u'fawikinews': {u'badges': [],
#     u'site': u'fawikinews',
#     u'title': u'\u0631\u062f\u0647:\u0627\u0633\u06a9\u0627\u062a\u0644\u0646\u062f'},
#    u'fawikivoyage': {u'badges': [],
#     u'site': u'fawikivoyage',
#     u'title': u'\u0627\u0633\u06a9\u0627\u062a\u0644\u0646\u062f'},
#    u'fiu_vrowiki': {u'badges': [],
#     u'site': u'fiu_vrowiki',
#     u'title': u'Sotimaa'},
#    u'fiwiki': {u'badges': [], u'site': u'fiwiki', u'title': u'Skotlanti'},
#    u'fiwikivoyage': {u'badges': [],
#     u'site': u'fiwikivoyage',
#     u'title': u'Skotlanti'},
#    u'fowiki': {u'badges': [], u'site': u'fowiki', u'title': u'Skotland'},
#    u'frrwiki': {u'badges': [], u'site': u'frrwiki', u'title': u'Skotlun'},
#    u'frwiki': {u'badges': [], u'site': u'frwiki', u'title': u'\xc9cosse'},
#    u'frwikinews': {u'badges': [],
#     u'site': u'frwikinews',
#     u'title': u'Cat\xe9gorie:\xc9cosse'},
#    u'frwikivoyage': {u'badges': [],
#     u'site': u'frwikivoyage',
#     u'title': u'\xc9cosse'},
#    u'fywiki': {u'badges': [], u'site': u'fywiki', u'title': u'Skotl\xe2n'},
#    u'gawiki': {u'badges': [], u'site': u'gawiki', u'title': u'Albain'},
#    u'gdwiki': {u'badges': [], u'site': u'gdwiki', u'title': u'Alba'},
#    u'glkwiki': {u'badges': [],
#     u'site': u'glkwiki',
#     u'title': u'\u0627\u0633\u0643\u0627\u062a\u0644\u0646\u062f'},
#    u'glwiki': {u'badges': [], u'site': u'glwiki', u'title': u'Escocia'},
#    u'gnwiki': {u'badges': [], u'site': u'gnwiki', u'title': u'Ekosia'},
#    u'gomwiki': {u'badges': [],
#     u'site': u'gomwiki',
#     u'title': u'\u0938\u094d\u0915\u0949\u091f\u0932\u0902\u0921'},
#    u'gvwiki': {u'badges': [], u'site': u'gvwiki', u'title': u'Nalbin'},
#    u'hakwiki': {u'badges': [], u'site': u'hakwiki', u'title': u'Scotland'},
#    u'hewiki': {u'badges': [],
#     u'site': u'hewiki',
#     u'title': u'\u05e1\u05e7\u05d5\u05d8\u05dc\u05e0\u05d3'},
#    u'hewikivoyage': {u'badges': [],
#     u'site': u'hewikivoyage',
#     u'title': u'\u05e1\u05e7\u05d5\u05d8\u05dc\u05e0\u05d3'},
#    u'hifwiki': {u'badges': [], u'site': u'hifwiki', u'title': u'Scotland'},
#    u'hiwiki': {u'badges': [],
#     u'site': u'hiwiki',
#     u'title': u'\u0938\u094d\u0915\u0949\u091f\u094d\u0932\u0948\u0923\u094d\u0921'},
#    u'hrwiki': {u'badges': [], u'site': u'hrwiki', u'title': u'\u0160kotska'},
#    u'hsbwiki': {u'badges': [], u'site': u'hsbwiki', u'title': u'\u0160otiska'},
#    u'htwiki': {u'badges': [], u'site': u'htwiki', u'title': u'Ek\xf2s'},
#    u'huwiki': {u'badges': [], u'site': u'huwiki', u'title': u'Sk\xf3cia'},
#    u'huwikinews': {u'badges': [],
#     u'site': u'huwikinews',
#     u'title': u'Kateg\xf3ria:Sk\xf3cia'},
#    u'hywiki': {u'badges': [],
#     u'site': u'hywiki',
#     u'title': u'\u0547\u0578\u057f\u056c\u0561\u0576\u0564\u056b\u0561'},
#    u'iawiki': {u'badges': [], u'site': u'iawiki', u'title': u'Scotia'},
#    u'idwiki': {u'badges': [], u'site': u'idwiki', u'title': u'Skotlandia'},
#    u'iewiki': {u'badges': [], u'site': u'iewiki', u'title': u'Scotia'},
#    u'ilowiki': {u'badges': [], u'site': u'ilowiki', u'title': u'Eskosia'},
#    u'iowiki': {u'badges': [], u'site': u'iowiki', u'title': u'Skotia'},
#    u'iswiki': {u'badges': [], u'site': u'iswiki', u'title': u'Skotland'},
#    u'itwiki': {u'badges': [], u'site': u'itwiki', u'title': u'Scozia'},
#    u'itwikinews': {u'badges': [],
#     u'site': u'itwikinews',
#     u'title': u'Categoria:Scozia'},
#    u'itwikiquote': {u'badges': [],
#     u'site': u'itwikiquote',
#     u'title': u'Scozia'},
#    u'itwikivoyage': {u'badges': [],
#     u'site': u'itwikivoyage',
#     u'title': u'Scozia'},
#    u'jawiki': {u'badges': [],
#     u'site': u'jawiki',
#     u'title': u'\u30b9\u30b3\u30c3\u30c8\u30e9\u30f3\u30c9'},
#    u'jvwiki': {u'badges': [], u'site': u'jvwiki', u'title': u'Skotlandia'},
#    u'kaawiki': {u'badges': [], u'site': u'kaawiki', u'title': u'Shotlandiya'},
#    u'kawiki': {u'badges': [],
#     u'site': u'kawiki',
#     u'title': u'\u10e8\u10dd\u10e2\u10da\u10d0\u10dc\u10d3\u10d8\u10d0'},
#    u'kkwiki': {u'badges': [],
#     u'site': u'kkwiki',
#     u'title': u'\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0438\u044f'},
#    u'kmwiki': {u'badges': [],
#     u'site': u'kmwiki',
#     u'title': u'\u1794\u17d2\u179a\u1791\u17c1\u179f\u179f\u17d2\u1780\u17bb\u178f\u17a1\u17c2\u1793'},
#    u'knwiki': {u'badges': [],
#     u'site': u'knwiki',
#     u'title': u'\u0cb8\u0ccd\u0c95\u0cbe\u0c9f\u0ccd\u200c\u0cb2\u0cc6\u0c82\u0ca1\u0ccd'},
#    u'kowiki': {u'badges': [],
#     u'site': u'kowiki',
#     u'title': u'\uc2a4\ucf54\ud2c0\ub79c\ub4dc'},
#    u'krcwiki': {u'badges': [],
#     u'site': u'krcwiki',
#     u'title': u'\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0438\u044f'},
#    u'kshwiki': {u'badges': [], u'site': u'kshwiki', u'title': u'Schottland'},
#    u'kuwiki': {u'badges': [], u'site': u'kuwiki', u'title': u'Skotlenda'},
#    u'kvwiki': {u'badges': [],
#     u'site': u'kvwiki',
#     u'title': u'\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0438\u044f'},
#    u'kwwiki': {u'badges': [], u'site': u'kwwiki', u'title': u'Alban'},
#    u'kywiki': {u'badges': [],
#     u'site': u'kywiki',
#     u'title': u'\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0438\u044f'},
#    u'ladwiki': {u'badges': [], u'site': u'ladwiki', u'title': u'Eskosia'},
#    u'lawiki': {u'badges': [], u'site': u'lawiki', u'title': u'Scotia'},
#    u'lbwiki': {u'badges': [], u'site': u'lbwiki', u'title': u'Schottland'},
#    u'lijwiki': {u'badges': [], u'site': u'lijwiki', u'title': u'Sc\xf2\xe7ia'},
#    u'liwiki': {u'badges': [], u'site': u'liwiki', u'title': u'Sjotland'},
#    u'lmowiki': {u'badges': [], u'site': u'lmowiki', u'title': u'Scozia'},
#    u'lnwiki': {u'badges': [], u'site': u'lnwiki', u'title': u'Ek\xf3si'},
#    u'lowiki': {u'badges': [],
#     u'site': u'lowiki',
#     u'title': u'\u0e9b\u0eb0\u0ec0\u0e97\u0e94\u0ec0\u0ead\u0e81\u0ebb\u0e94'},
#    u'ltwiki': {u'badges': [], u'site': u'ltwiki', u'title': u'\u0160kotija'},
#    u'lvwiki': {u'badges': [], u'site': u'lvwiki', u'title': u'Skotija'},
#    u'miwiki': {u'badges': [], u'site': u'miwiki', u'title': u'Koterana'},
#    u'mkwiki': {u'badges': [],
#     u'site': u'mkwiki',
#     u'title': u'\u0428\u043a\u043e\u0442\u0441\u043a\u0430'},
#    u'mlwiki': {u'badges': [],
#     u'site': u'mlwiki',
#     u'title': u'\u0d38\u0d4d\u0d15\u0d4b\u0d1f\u0d4d\u0d1f\u0d4d\u200c\u0d32\u0d7b\u0d21\u0d4d'},
#    u'mnwiki': {u'badges': [],
#     u'site': u'mnwiki',
#     u'title': u'\u0428\u043e\u0442\u043b\u0430\u043d\u0434'},
#    u'mrwiki': {u'badges': [],
#     u'site': u'mrwiki',
#     u'title': u'\u0938\u094d\u0915\u0949\u091f\u0932\u0902\u0921'},
#    u'mswiki': {u'badges': [], u'site': u'mswiki', u'title': u'Scotland'},
#    u'mtwiki': {u'badges': [], u'site': u'mtwiki', u'title': u'Skozja'},
#    u'mywiki': {u'badges': [],
#     u'site': u'mywiki',
#     u'title': u'\u1005\u1000\u1031\u102c\u1037\u1010\u101c\u1014\u103a\u1014\u102d\u102f\u1004\u103a\u1004\u1036'},
#    u'mznwiki': {u'badges': [],
#     u'site': u'mznwiki',
#     u'title': u'\u0627\u0633\u06a9\u0627\u062a\u0644\u0646\u062f'},
#    u'nds_nlwiki': {u'badges': [],
#     u'site': u'nds_nlwiki',
#     u'title': u'Schotlaand'},
#    u'ndswiki': {u'badges': [], u'site': u'ndswiki', u'title': u'Schottland'},
#    u'newiki': {u'badges': [],
#     u'site': u'newiki',
#     u'title': u'\u0938\u094d\u0915\u091f\u0932\u094d\u092f\u093e\u0928\u094d\u0921'},
#    u'nlwiki': {u'badges': [], u'site': u'nlwiki', u'title': u'Schotland'},
#    u'nlwikivoyage': {u'badges': [],
#     u'site': u'nlwikivoyage',
#     u'title': u'Schotland'},
#    u'nnwiki': {u'badges': [], u'site': u'nnwiki', u'title': u'Skottland'},
#    u'novwiki': {u'badges': [], u'site': u'novwiki', u'title': u'Skotia'},
#    u'nowiki': {u'badges': [u'Q17437798'],
#     u'site': u'nowiki',
#     u'title': u'Skottland'},
#    u'nowikinews': {u'badges': [],
#     u'site': u'nowikinews',
#     u'title': u'Kategori:Skottland'},
#    u'nrmwiki': {u'badges': [], u'site': u'nrmwiki', u'title': u'\xcacosse'},
#    u'ocwiki': {u'badges': [], u'site': u'ocwiki', u'title': u'Esc\xf2cia'},
#    u'oswiki': {u'badges': [],
#     u'site': u'oswiki',
#     u'title': u'\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0438'},
#    u'pamwiki': {u'badges': [], u'site': u'pamwiki', u'title': u'Scotland'},
#    u'papwiki': {u'badges': [], u'site': u'papwiki', u'title': u'Eskosia'},
#    u'pawiki': {u'badges': [],
#     u'site': u'pawiki',
#     u'title': u'\u0a38\u0a15\u0a3e\u0a1f\u0a32\u0a48\u0a02\u0a21'},
#    u'pcdwiki': {u'badges': [], u'site': u'pcdwiki', u'title': u'\xc9cosse'},
#    u'pihwiki': {u'badges': [], u'site': u'pihwiki', u'title': u'Skotlund'},
#    u'plwiki': {u'badges': [], u'site': u'plwiki', u'title': u'Szkocja'},
#    u'plwikinews': {u'badges': [],
#     u'site': u'plwikinews',
#     u'title': u'Kategoria:Szkocja'},
#    u'plwikivoyage': {u'badges': [],
#     u'site': u'plwikivoyage',
#     u'title': u'Szkocja'},
#    u'pmswiki': {u'badges': [], u'site': u'pmswiki', u'title': u'Sc\xf2ssia'},
#    u'pnbwiki': {u'badges': [],
#     u'site': u'pnbwiki',
#     u'title': u'\u0633\u06a9\u0627\u0679\u0644\u06cc\u0646\u0688'},
#    u'ptwiki': {u'badges': [], u'site': u'ptwiki', u'title': u'Esc\xf3cia'},
#    u'ptwikinews': {u'badges': [],
#     u'site': u'ptwikinews',
#     u'title': u'Categoria:Esc\xf3cia'},
#    u'ptwikivoyage': {u'badges': [],
#     u'site': u'ptwikivoyage',
#     u'title': u'Esc\xf3cia'},
#    u'quwiki': {u'badges': [], u'site': u'quwiki', u'title': u'Iskusya'},
#    u'rmwiki': {u'badges': [], u'site': u'rmwiki', u'title': u'Scozia'},
#    u'roa_rupwiki': {u'badges': [],
#     u'site': u'roa_rupwiki',
#     u'title': u'Scotlandia'},
#    u'rowiki': {u'badges': [], u'site': u'rowiki', u'title': u'Sco\u021bia'},
#    u'ruwiki': {u'badges': [],
#     u'site': u'ruwiki',
#     u'title': u'\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0438\u044f'},
#    u'ruwikinews': {u'badges': [],
#     u'site': u'ruwikinews',
#     u'title': u'\u041a\u0430\u0442\u0435\u0433\u043e\u0440\u0438\u044f:\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0438\u044f'},
#    u'ruwikivoyage': {u'badges': [],
#     u'site': u'ruwikivoyage',
#     u'title': u'\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0438\u044f'},
#    u'scnwiki': {u'badges': [], u'site': u'scnwiki', u'title': u'Scozzia'},
#    u'scowiki': {u'badges': [], u'site': u'scowiki', u'title': u'Scotland'},
#    u'scwiki': {u'badges': [], u'site': u'scwiki', u'title': u'Iscotzia'},
#    u'shwiki': {u'badges': [], u'site': u'shwiki', u'title': u'\u0160kotska'},
#    u'simplewiki': {u'badges': [],
#     u'site': u'simplewiki',
#     u'title': u'Scotland'},
#    u'siwiki': {u'badges': [],
#     u'site': u'siwiki',
#     u'title': u'\u0dc3\u0dca\u0d9a\u0ddc\u0da7\u0dca\u0dbd\u0db1\u0dca\u0dad\u0dba'},
#    u'skwiki': {u'badges': [],
#     u'site': u'skwiki',
#     u'title': u'\u0160k\xf3tsko'},
#    u'slwiki': {u'badges': [], u'site': u'slwiki', u'title': u'\u0160kotska'},
#    u'smwiki': {u'badges': [], u'site': u'smwiki', u'title': u'Sikotilani'},
#    u'snwiki': {u'badges': [], u'site': u'snwiki', u'title': u'Scotland'},
#    u'sowiki': {u'badges': [], u'site': u'sowiki', u'title': u'Skotland'},
#    u'sqwiki': {u'badges': [u'Q17437796'],
#     u'site': u'sqwiki',
#     u'title': u'Skocia'},
#    u'sqwikinews': {u'badges': [],
#     u'site': u'sqwikinews',
#     u'title': u'Kategoria:Skoci'},
#    u'srwiki': {u'badges': [],
#     u'site': u'srwiki',
#     u'title': u'\u0428\u043a\u043e\u0442\u0441\u043a\u0430'},
#    u'srwikinews': {u'badges': [],
#     u'site': u'srwikinews',
#     u'title': u'\u041a\u0430\u0442\u0435\u0433\u043e\u0440\u0438\u0458\u0430:\u0428\u043a\u043e\u0442\u0441\u043a\u0430'},
#    u'sswiki': {u'badges': [], u'site': u'sswiki', u'title': u'Sikoshilandi'},
#    u'stqwiki': {u'badges': [], u'site': u'stqwiki', u'title': u'Skotlound'},
#    u'suwiki': {u'badges': [], u'site': u'suwiki', u'title': u'Skotlandia'},
#    u'svwiki': {u'badges': [], u'site': u'svwiki', u'title': u'Skottland'},
#    u'svwikinews': {u'badges': [],
#     u'site': u'svwikinews',
#     u'title': u'Kategori:Skottland'},
#    u'svwikivoyage': {u'badges': [],
#     u'site': u'svwikivoyage',
#     u'title': u'Skottland'},
#    u'swwiki': {u'badges': [], u'site': u'swwiki', u'title': u'Uskoti'},
#    u'szlwiki': {u'badges': [], u'site': u'szlwiki', u'title': u'Szkocyjo'},
#    u'tawiki': {u'badges': [],
#     u'site': u'tawiki',
#     u'title': u'\u0b87\u0b9a\u0bc1\u0b95\u0bcd\u0b95\u0bca\u0b9f\u0bcd\u0bb2\u0bbe\u0ba8\u0bcd\u0ba4\u0bc1'},
#    u'tetwiki': {u'badges': [], u'site': u'tetwiki', u'title': u'Esk\xf3sia'},
#    u'tewiki': {u'badges': [],
#     u'site': u'tewiki',
#     u'title': u'\u0c38\u0c4d\u0c15\u0c3e\u0c1f\u0c4d\u0c32\u0c3e\u0c02\u0c21\u0c4d'},
#    u'tgwiki': {u'badges': [],
#     u'site': u'tgwiki',
#     u'title': u'\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0438\u044f'},
#    u'thwiki': {u'badges': [],
#     u'site': u'thwiki',
#     u'title': u'\u0e1b\u0e23\u0e30\u0e40\u0e17\u0e28\u0e2a\u0e01\u0e2d\u0e15\u0e41\u0e25\u0e19\u0e14\u0e4c'},
#    u'tlwiki': {u'badges': [], u'site': u'tlwiki', u'title': u'Scotland'},
#    u'tpiwiki': {u'badges': [], u'site': u'tpiwiki', u'title': u'Skotlan'},
#    u'trwiki': {u'badges': [],
#     u'site': u'trwiki',
#     u'title': u'\u0130sko\xe7ya'},
#    u'trwikinews': {u'badges': [],
#     u'site': u'trwikinews',
#     u'title': u'Kategori:\u0130sko\xe7ya'},
#    u'ttwiki': {u'badges': [u'Q17437798'],
#     u'site': u'ttwiki',
#     u'title': u'\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0438\u044f'},
#    u'ugwiki': {u'badges': [], u'site': u'ugwiki', u'title': u'Shotlandiye'},
#    u'ukwiki': {u'badges': [],
#     u'site': u'ukwiki',
#     u'title': u'\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0456\u044f'},
#    u'ukwikivoyage': {u'badges': [],
#     u'site': u'ukwikivoyage',
#     u'title': u'\u0428\u043e\u0442\u043b\u0430\u043d\u0434\u0456\u044f'},
#    u'urwiki': {u'badges': [],
#     u'site': u'urwiki',
#     u'title': u'\u0633\u06a9\u0627\u0679 \u0644\u06cc\u0646\u0688'},
#    u'uzwiki': {u'badges': [], u'site': u'uzwiki', u'title': u'Shotlandiya'},
#    u'vecwiki': {u'badges': [], u'site': u'vecwiki', u'title': u'Scozia'},
#    u'vepwiki': {u'badges': [],
#     u'site': u'vepwiki',
#     u'title': u'\u0160otlandii'},
#    u'viwiki': {u'badges': [], u'site': u'viwiki', u'title': u'Scotland'},
#    u'viwikivoyage': {u'badges': [],
#     u'site': u'viwikivoyage',
#     u'title': u'Scotland'},
#    u'vlswiki': {u'badges': [], u'site': u'vlswiki', u'title': u'Schotland'},
#    u'vowiki': {u'badges': [], u'site': u'vowiki', u'title': u'Skot\xe4n'},
#    u'warwiki': {u'badges': [], u'site': u'warwiki', u'title': u'Escocia'},
#    u'wawiki': {u'badges': [], u'site': u'wawiki', u'title': u'Esc\xf4sse'},
#    u'wuuwiki': {u'badges': [],
#     u'site': u'wuuwiki',
#     u'title': u'\u82cf\u683c\u5170'},
#    u'xalwiki': {u'badges': [],
#     u'site': u'xalwiki',
#     u'title': u'\u0421\u043a\u043e\u0442\u0438\u0448\u0438\u043d \u0422\u0430\u04a3\u04bb\u0447'},
#    u'xmfwiki': {u'badges': [],
#     u'site': u'xmfwiki',
#     u'title': u'\u10e8\u10dd\u10e2\u10da\u10d0\u10dc\u10d3\u10d8\u10d0'},
#    u'yiwiki': {u'badges': [],
#     u'site': u'yiwiki',
#     u'title': u'\u05e1\u05e7\u05d0\u05d8\u05dc\u05d0\u05e0\u05d3'},
#    u'yowiki': {u'badges': [],
#     u'site': u'yowiki',
#     u'title': u'Sk\u1ecd\u0301tl\xe1nd\xec'},
#    u'zeawiki': {u'badges': [], u'site': u'zeawiki', u'title': u'Schotland'},
#    u'zh_classicalwiki': {u'badges': [],
#     u'site': u'zh_classicalwiki',
#     u'title': u'\u8607\u683c\u862d'},
#    u'zh_min_nanwiki': {u'badges': [],
#     u'site': u'zh_min_nanwiki',
#     u'title': u'So\u0358-kek-l\xe2n'},
#    u'zh_yuewiki': {u'badges': [],
#     u'site': u'zh_yuewiki',
#     u'title': u'\u8607\u683c\u862d'},
#    u'zhwiki': {u'badges': [],
#     u'site': u'zhwiki',
#     u'title': u'\u8607\u683c\u862d'},
#    u'zhwikinews': {u'badges': [],
#     u'site': u'zhwikinews',
#     u'title': u'Category:\u8607\u683c\u862d'},
#    u'zhwikivoyage': {u'badges': [],
#     u'site': u'zhwikivoyage',
#     u'title': u'\u82cf\u683c\u5170'},
#    u'zuwiki': {u'badges': [], u'site': u'zuwiki', u'title': u'IsiKotilandi'}},
#   u'type': u'item'}]

# %% [markdown]
# # Instance of

# %%
def parseInstanceOf(i):
    res = []
    try:
        if 'P31' in i['claims'].keys():
            for c in i['claims']['P31']:
                res.append(json.dumps({'child':i['id'], 'parent':c['mainsnak']['datavalue']['value']['id']}))
    except:
        return res
    
    return res

# %%
instances = data.flatMap(parseInstanceOf).cache()

# %%
instances.count()
# Out:
# 20547613

# %%
instances.take(10)
# Out:
# ['{"parent": "Q3336843", "child": "Q22"}',
#  '{"parent": "Q3624078", "child": "Q31"}',
#  '{"parent": "Q43702", "child": "Q31"}',
#  '{"parent": "Q185441", "child": "Q31"}',
#  '{"parent": "Q6256", "child": "Q31"}',
#  '{"parent": "Q160016", "child": "Q31"}',
#  '{"parent": "Q6505795", "child": "Q31"}',
#  '{"parent": "Q1454986", "child": "Q1"}',
#  '{"parent": "Q175854", "child": "Q13"}',
#  '{"parent": "Q5", "child": "Q23"}']

# %%
instances.saveAsTextFile("hdfs://hdfs-mesos/user/simonj/data/wikidata-20170313_instances")

# %% [markdown]
# # Subclass of

# %%
def parseSubclassOf(i):
    res = []
    try:
        if 'P279' in i['claims']:
            for c in i['claims']['P279']:
                res.append(json.dumps({'child':i['id'], 'parent':c['mainsnak']['datavalue']['value']['id']}))
    except:
        return res
    
    return res

# %%
subclasses = data.flatMap(parseSubclassOf).cache()

# %%
subclasses.count()
# Out:
# 2160029

# %%
subclasses.take(10)
# Out:
# ['{"parent": "Q37141", "child": "Q13"}',
#  '{"parent": "Q154", "child": "Q44"}',
#  '{"parent": "Q11019", "child": "Q82"}',
#  '{"parent": "Q4135602", "child": "Q102"}',
#  '{"parent": "Q41825", "child": "Q105"}',
#  '{"parent": "Q18602249", "child": "Q109"}',
#  '{"parent": "Q82955", "child": "Q116"}',
#  '{"parent": "Q18602249", "child": "Q124"}',
#  '{"parent": "Q18602249", "child": "Q126"}',
#  '{"parent": "Q41825", "child": "Q127"}']

# %%
subclasses.saveAsTextFile("hdfs://hdfs-mesos/user/simonj/data/wikidata-20170313_subclasses")

# %% [markdown]
# # Labels

# %%
def parseLabelOf(i):
    res = []
    for label in i['labels'].values():
        res.append(json.dumps({'id':i['id'], 'language':label['language'], 'value':label['value']}))
    return res

# %%
labels = data.flatMap(parseLabelOf).cache()

# %%
labels.count()
# Out:
# 134489309

# %%
labels.take(10)
# Out:
# ['{"value": "Nalbin", "id": "Q22", "language": "gv"}',
#  '{"value": "Scotland", "id": "Q22", "language": "sco"}',
#  '{"value": "Scozzia", "id": "Q22", "language": "scn"}',
#  '{"value": "\\u82cf\\u683c\\u5170", "id": "Q22", "language": "wuu"}',
#  '{"value": "S\\u016d-g\\u00e1ik-l\\u00e0ng", "id": "Q22", "language": "cdo"}',
#  '{"value": "\\u8607\\u683c\\u862d", "id": "Q22", "language": "zh-hk"}',
#  '{"value": "Alba", "id": "Q22", "language": "gd"}',
#  '{"value": "Esc\\u00f3cia", "id": "Q22", "language": "pt-br"}',
#  '{"value": "Albain", "id": "Q22", "language": "ga"}',
#  '{"value": "Ekosia", "id": "Q22", "language": "gn"}']

# %%
labels.saveAsTextFile("hdfs://hdfs-mesos/user/simonj/data/wikidata-20170313_labels")

# %% [markdown]
# # Aliases

# %%
def parseAliasOf(i):
    res = []
    if 'aliases' in i:
        for aliases in i['aliases'].values():
            for alias in aliases:
                res.append(json.dumps({'id':i['id'], 'language':alias['language'], 'value':alias['value']}))
    return res

# %%
aliases = data.flatMap(parseAliasOf).cache()

# %%
aliases.count()
# Out:
# 13588187

# %%
aliases.take(10)
# Out:
# ['{"value": "Caledonia", "id": "Q22", "language": "en-gb"}',
#  '{"value": "Skotio", "id": "Q22", "language": "eo"}',
#  '{"value": "Skotujo", "id": "Q22", "language": "eo"}',
#  '{"value": "Alba", "id": "Q22", "language": "en"}',
#  '{"value": "Scotland, United Kingdom", "id": "Q22", "language": "en"}',
#  '{"value": "SCT", "id": "Q22", "language": "en"}',
#  '{"value": "Caledonia", "id": "Q22", "language": "en"}',
#  '{"value": "scot", "id": "Q22", "language": "en"}',
#  '{"value": "Kaledonija", "id": "Q22", "language": "hr"}',
#  '{"value": "Scotland", "id": "Q22", "language": "ca"}']

# %%
aliases.saveAsTextFile("hdfs://hdfs-mesos/user/simonj/data/wikidata-20170313_aliases")
