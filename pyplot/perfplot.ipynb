# %%
from matplotlib.pyplot import *

plot([3.03, 5.25, 11.08, 22.87, 44.01, 94.51], [329.1, 380.37, 360.59, 349.56, 363.08, 337.63], label="Python 3.4 DC", marker='x')
plot([3.14, 6.05, 12.3, 25.12, 50.61, 100.71], [317.98, 330.07, 325.04, 318.18, 315.69, 306.72], label="Python 2.7 DC", marker='+')
plot([37.23, 39.22, 40.31, 42.82, 48.56, 94.51], [26.85, 50.97, 99.15, 186.66, 329.05, 337.63], label="Python 3.4 Remote", marker='v')
plot([37.43, 40.07, 48.65, 60.31, 63.37, 104.72], [26.71, 49.89, 82.19, 132.49, 252.14, 304.74], label="Python 2.7 Remote", marker='o')
legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=2, mode="expand", borderaxespad=0.)
ylim(0, 400)
ylabel('requests per second')
xlim(0, 110)
xlabel('latency')
figsize=(3000,100)
show()
